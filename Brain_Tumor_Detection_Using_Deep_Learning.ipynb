# %% [markdown]
# <a href="https://colab.research.google.com/github/yasirdharejo786/Brain_Tumor_MRI_Using_Deep_Learning/blob/main/Brain_Tumor_Detection_Using_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import pandas as pd
import random

from PIL import Image, ImageEnhance

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG16

from sklearn.utils import shuffle

# %%
print(os.listdir('/content/drive'))
# Out:
# ['MyDrive', '.shortcut-targets-by-id', '.Trash-0', '.Encrypted']

# %%
print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['Colab Notebooks', 'Snapchat-265397900_resized.jpg', 'Snapchat-642219112.jpg', 'Abc.gdoc', 'FORM.gdoc', 'Classroom', 'yasir ali.pdf', 'charsheet .pdf', 'html_copy.pdf', 'HTML Attributes.pdf', 'Excel formulas.pdf', 'MS Excel.pdf', 'case studyof retail process .pdf', 'Copy of Human Resource Management by Slidesgo.gslides', 'IMG-20251207-WA0000 (1).jpg', 'IMG-20251207-WA0000.jpg', 'Untitled spreadsheet (1).gsheet', 'Untitled spreadsheet.gsheet', 'Aero_Rescue_AI_Safety_IntelligenceFinal.pptx', 'CV.pdf', '1774101761426.jpg', '_copy.pdf', 'Agentic AI ', 'Blue and White Modern Professional Resume_20260507_124114_0000 (1).pdf', 'Blue and White Modern Professional Resume_20260507_124114_0000.pdf', 'yasir_recommendation.pdf', 'Laptop Scholarship 2026-2027 university certificate.docx', 'MRI images', 'MRI Images.zip']

# %%
import os

# Directories
train_dir = '/content/drive/MyDrive/MRI images/Testing'
test_dir = '/content/drive/MyDrive/MRI images/Training'

train_paths = []
train_labels = []
test_paths = []

for label in os.listdir(train_dir):
  for image in os.listdir(os.path.join(train_dir, label)):
    train_paths.append(os.path.join(train_dir, label, image))
    train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)
print(train_paths[:10])
# Out:
# []
